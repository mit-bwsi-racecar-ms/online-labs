# %%
# FIRST import all the necessary libraries and modules!
import cv2               # import OpenCV
import numpy as np       # import NumPy

# import instructor made functions 
import sys
sys.path.insert(0, '../..')
from utils import *

# %% [markdown]
# # Color Trackbars
#
# <p style='font-size:1.75rem;line-height:1.5'>
#     In this lab, we will learn how to <b style="color:green">create trackbars</b> and use them to help us understand <b style="color:blue">B</b><b style="color:green">G</b><b style="color:red">R</b> and <b style="color:#072F5F">H</b><b style="color:#3895D3">S</b><b style="color:#58CCED">V</b> color.
#     </p>
#
# <img src="bgr_vs_hsv.png" alt="bgr_vs_hsv" style="width: 500px;"/>
#
# <p style='font-size:1.75rem;line-height:1.5'>
#     Functions we will learn in this lab include:
#     <ul style='font-size:1.75rem;line-height:2'>
#         <li>Creating a trackbar: <code>cv2.createTrackbar</code></li>
#         <li>Getting trackbar values: <code>cv2.getTrackbarPos</code></li>
#         <li>Understanding mouse events: <code>cv2.setMouseCallback</code></li>
#     </ul>
# </p>

# %% [markdown]
# ## Create a Trackbar
#
# <p style='font-size:1.75rem;line-height:1.5'>
#     We can add a trackbar to a window using the function <code>cv2.createTrackbar</code>. It has the following format:
#     </p>
#
# ```python
# cv2.createTrackbar(<trackbar_name>, <window_name>, <min_value>, <max_value>, <callback_function>)
# ```
#
# <p style='font-size:1.75rem;line-height:1.5'>
# This trackbar would look like this:
#     </p>
#
# <img src="trackbar.png" alt="trackbar" style="width: 300px;"/>
#
# <p style='font-size:1.75rem;line-height:1.5'>
#     <b style="color:red">Exercise:</b>
#     <br> Make your own trackbar below with the following inputs.
#     <ul style='font-size:1.75rem;line-height:2'>
#         <li>trackbar_name: <code>"My Trackbar"</code></li>
#         <li>min_value: <code>0</code></li>
#         <li>max_value: <code>10</code></li>
#         <li>callback_function: <code>callback</code></li>
#         <li>Use the defined <code>window_name</code></li>
#     </ul>
#     </p>

# %%
img = np.zeros((500, 500, 3), np.uint8)   # creates a blank black image
window_name = 'Trackbar'                  # stores the name of the window
cv2.imshow(window_name, img)              # creates window and shows image

def callback(value):                      # do nothing
    pass

# TASK: Create your trackbar here. 
# (hint make sure you use "window_name" defined above!)


close_windows()     # press 'ESC' to close pop-up window

# %% [markdown]
# ## Reading a Trackbar
#
# <p style='font-size:1.75rem;line-height:1.5'>
#     We can get the value of a trackbar using <code>cv2.getTrackbarPos</code>. It has the format:
#     </p>
#
# ```python
# trackbar_value = cv2.getTrackbarPos(<trackbar_name>, <window_name>)
# ```
#
# <p style='font-size:1.75rem;line-height:1.5'>
#     <b style="color:red">Exercise:</b>
#     <br> Read and print the value of the trackbar below.
#     </p>

# %%
img = np.zeros((500, 500, 3), np.uint8)               # creates a blank black image
window_name = 'Trackbar'                              # stores the name of the window
cv2.imshow(window_name, img)                          # creates window and shows image

def callback(value):
    # TASK #1: Save the trackbar value using cv2.getTrackbarPos
    
    
    # TASK #2: Print the value
    

cv2.createTrackbar('My Trackbar', window_name, 0, 10, callback)  # creates a trackbar
close_windows()     # press 'ESC' to close pop-up window

# %% [markdown]
# ## BGR Color
#
# <p style='font-size:1.75rem;line-height:1.5'>
#     <b style="color:blue">Blue</b>, <b style="color:green">green</b>, and <b style="color:red">red</b> are the primary colors when you are mixing light. This is <b>called additive color mixing</b>. <b style="color:blue">B</b><b style="color:green">G</b><b style="color:red">R</b> values range from <code>0</code> (black) to <code>255</code> (white).
#     </p>
#
# ![BGR](bgr.png)
#
# <p style='font-size:1.75rem;line-height:1.5'>
#     <b style="color:red">Exercise:</b>
#     <br> In the code below:
#     <ul style='font-size:1.75rem;line-height:2'>
#         <li><b style="color:blue">Read and Save</b> the current values of the three trackbars. </li>
#         <li><b style="color:green">Draw a rectangle</b> over the entire screen with the corresponding color.</li>
#         <li><b style="color:orange">Move the trackbars</b> around to understand how <b>additive color mixing</b> works.</li>
#     </ul>
#     </p>
#
# <p style='font-size:1.75rem;line-height:1.5'>
#     This <b>BGR trackbar</b> would look like this:
#     </p>
#
# <img src="bgr_trackbar.png" alt="bgr_trackbar" style="width: 300px;"/>
#
# <p style='font-size:1.75rem;line-height:1.5'>
#     Hint! Use the <code>getTrackbarPos</code> and <code>cv2.rectangle</code> functions we learned from before!
#     </p>

# %%
img = np.zeros((500, 500, 3), np.uint8)     # creates a blank black image
window_name = 'BGR Trackbars'               # stores the name of the window
cv2.imshow(window_name, img)                # creates window and shows image

def callback(value):
    # TASK #1: Set b, g, and r variables to current values of corresponding trackbars
    # (hint The variable "window_name" stores the window name)
    
    
    
    fill_img(b, g, r)                                  # calls fill_img with this color
    cv2.putText(img, 'BGR: {}'.format((b, g, r)), (10, 35), 0, 0.75, (255, 255, 255), 2)
    cv2.imshow(window_name, img)                       # displays updated image in window

cv2.createTrackbar('Blue', window_name, 0, 255, callback)   # create 'Blue' trackbar, from 0 to 255
cv2.createTrackbar('Green', window_name, 0, 255, callback)  # create 'Green' trackbar, from 0 to 255
cv2.createTrackbar('Red', window_name, 0, 255, callback)    # create 'Red' trackbar, from 0 to 255

def fill_img(b, g, r):
    # TASK #2: Draw a filled in rectangle of the chosen color over the entire image
    # (hint Use -1 as thickness to fill the rectangle!)
    
    
    
    
close_windows()

# %% [markdown]
# ## HSV Color
#
# <p style='font-size:1.75rem;line-height:1.5'>
#     So far, we have used <b style="color:blue">B</b><b style="color:green">G</b><b style="color:red">R</b> color. There is another form of color called <b style="color:#072F5F">H</b><b style="color:#3895D3">S</b><b style="color:#58CCED">V</b>, which stands for hue, saturation, and value.
#     </p>
#
# <ul style='font-size:1.75rem;line-height:1.5'>
#     <li><b style="color:#072F5F">Hue</b> corresponds to the <b>color</b>, from 0 to 179.</li>
#     <li><b style="color:#3895D3">Saturation</b> corresponds to the <b>colorfulness</b>, from 0 to 255.</li>
#     <li><b style="color:#58CCED">Value</b> corresponds to <b>brightness</b>, from 0 to 255</li>
# </ul>
#
# ![HSV](hsv.png)
#
# <p style='font-size:1.75rem;line-height:1.5'>
#     <b style="color:red">Exercise:</b>
#     <br> In the code below:
#     <ul style='font-size:1.75rem;line-height:2'>
#         <li><b style="color:blue">Read and Save</b> the current values of the three trackbars. </li>
#         <li><b style="color:green">Draw a rectangle</b> over the entire screen with the corresponding color.</li>
#         <li><b style="color:orange">Move the trackbars</b> around to understand how <b>HSV color mixing</b> works.</li>
#     </ul>
#     </p>
#
# <p style='font-size:1.75rem;line-height:1.5'>
#     This <b>HSV trackbar</b> would look like this:
#     </p>
#
# <img src="hsv_trackbar.png" alt="hsv_trackbar" style="width: 300px;"/>
#
# <p style='font-size:1.75rem;line-height:1.5'>
#     Hint! This is similar to the BGR Trackbar from above.
#     <br> Use the <code>getTrackbarPos</code> and <code>cv2.rectangle</code> functions we learned from before!
#     </p>

# %%
img = np.zeros((500, 500, 3), np.uint8)     # creates a blank black image
window_name = 'HSV Trackbars'               # stores the name of the window
cv2.imshow(window_name, img)                # creates window and shows image

def callback(value):
    # TASK #1: Set h, s, and v variables to current values of corresponding trackbars
    # (hint The variable "window_name" stores the window name)
    
    
    
    fill_img(h, s, v)                                       # calls fill_img with this color
    img_bgr = cv2.cvtColor(img, cv2.COLOR_HSV2BGR)          # converts image from hsv to bgr
    cv2.putText(img_bgr, 'HSV: {}'.format((h, s, v)), (10, 35), 0, 0.75, (255, 255, 255), 2)
    cv2.imshow(window_name, img_bgr)                        # displays updated image in window

cv2.createTrackbar('Hue', window_name, 0, 179, callback)         # create 'Hue' trackbar, from 0 to 179
cv2.createTrackbar('Saturation', window_name, 0, 255, callback)  # create 'Saturation' trackbar, from 0 to 255
cv2.createTrackbar('Value', window_name, 0, 255, callback)       # create 'Value' trackbar, from 0 to 255

def fill_img(h, s, v):
    # TASK #2: Draw a filled in rectangle of the chosen color over the entire image
    # (hint Use -1 as thickness to fill the rectangle!)
    
    

close_windows()

# %% [markdown]
# ---
# ---

# %% [markdown]
# # Mouse Drawing
#
# <p style='font-size:1.75rem;line-height:1.5'>
#     We can detect the mouse using the function <code>cv2.setMouseCallback</code>. It has the following format:
#     </p>
#
# ```python
# cv2.setMouseCallback(<window_name>, <callback_function>)
# ```
#
# <p style='font-size:1.75rem;line-height:1.5'>
#     The <b style='color:blue'>callback function</b> is called whenever a <b style='color:green'>mouse event</b> occurs. The event type and mouse location are passed in.
#     <br>
#
# <p style='font-size:1.75rem;line-height:1.5'>
#     We will use the <code>cv2.EVENT_LBUTTONDOWN</code> event, which occurs when the <b style='color:orange'>mouse is pressed down</b>.
#     </p>
#
# <img src="mouse_draw.png" alt="mouse_draw" style="width: 300px;"/>
#
# <p style='font-size:1.75rem;line-height:1.5'>
#     <b style="color:red">Exercise:</b>
#     <br> Fill in the code below to draw a shape when the mouse is pressed.
#     <br> Choose your own shapes, thicknesses, and colors!
#     </p>

# %%
img = np.zeros((500, 500, 3), np.uint8)   # creates a blank black image
window_name = 'Mouse Draw'                # stores the name of the window
cv2.imshow(window_name, img)                   # creates window and shows image

def callback(event, x, y, flags, params):
    if event == cv2.EVENT_LBUTTONDOWN:    # occurs when the mouse is pressed down
        draw_shape(x, y)                  # calls the draw_shape() function at this position
        cv2.imshow(window_name, img)           # redraws image (to reflect change)

cv2.setMouseCallback(window_name, callback)    # binds callback function to the window

def draw_shape(x, y):
    # TASK: Draw a shape (or multiple shapes!) here. 
    # Choose your own colors!
    
    
close_windows()

# %% [markdown]
# # Mouse and Trackbars
#
# <p style='font-size:1.75rem;line-height:1.5'>
#     Only do this lab if you have finished and understand everything so far.
#     </p>
#
# <p style='font-size:1.75rem;line-height:1.5'>
#     <b style="color:red">Exercise:</b>
#     <br> Write a program that combines <b>trackbars and mouse detection</b>. For example, you could have a trackbar that controls the <b>size</b>, <b>color</b>, or even the <b>shape</b>!:
#     <ul style='font-size:1.75rem;line-height:2'>
#         <li><b style="color:blue">Create a trackbar (or several)</b> to change aspects of the shape being drawn. </li>
#         <li><b style="color:green">Get the trackbar position </b> to read in values.</li>
#         <li><b style="color:orange">Draw shapes</b> based on the trackbar values.</li>
#     </ul>
#     </p>
#
# <p style='font-size:1.75rem;line-height:1.5'>
#     Here is an example of what you can make!
#     </p>
#
# <img src="mouse_and_trackbar.png" alt="mouse_and_trackbar" style="width: 300px;"/>
#
# <p style='font-size:1.75rem;line-height:1.5'>
#     Hint! Use <code>cv2.createTrackbar</code>, <code>cv2.getTrackbarPos</code>, and the different shape functions we've learned from before!
#     </p>

# %%
img = np.full((500, 500, 3), (255,255,255), np.uint8)   # creates a blank white image
window_name = 'Mouse and Trackbars'                     # stores the name of the window
cv2.imshow(window_name, img)                            # creates window and shows image

def trackbar_callback(value):
    pass                                         # do nothing (necessary for syntax)

def mouse_callback(event, x, y, flags, params):
    if event == cv2.EVENT_LBUTTONDOWN:           # occurs when the mouse is pressed down
        # TASK #2: Read in trackbar values
        
        
        
        # TASK #3: Draw shapes based on trackbars
        
        
        
        cv2.imshow(window_name, img)                  # redraws image (to reflect change)

cv2.setMouseCallback(window_name, mouse_callback)     # binds callback function to the window

# TASK #1: Create trackbars here



close_windows()
